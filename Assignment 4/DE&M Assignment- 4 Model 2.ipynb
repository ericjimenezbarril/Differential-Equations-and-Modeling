# %%
# Pràctica 4

# %%
# Model 2
# Trobar una corba tal que a cada punt la subtangent sigui
# igual al doble de l'abcissa (s'anomena la subtangent a y/y')

# %%
# En aquest cas ens donen pràcticament l'equació diferencial ja feta
#
# El que busquem és una funció y(x)
#
# tal que y(x)/y'(x) sigui igual a 2*x.
#
# y(x)/y'(x) = 2x
#
# Mirem de resoldre les equacions diferencials sense ajuda del SAGE
#

# %%
var("x y dx dy");eq1=y/(dy/dx)==2*x

# %%
# Mirem si podem separar variables

# %%
solve(eq1,dy)
# Out:
# [dy == 1/2*dx*y/x]

# %%
# Mirem si podem factoritzar la part dreta

# %%
factor(_[0].rhs())
# Out:
# 1/2*dx*y/x

# %%
# Passem totes les y's a l'esquerra i ara si ens ajudem del SAGE per fer les integrals, tot i que aquestes son trivials

#  (1/y) dy = (1/2) dx/x
 
# Recordem sempre d'afegir una constant. No cal una a cada banda. Actuen com una de sola.

# %%
var("k");integrate(1/y,y)==integrate(1/(2*x),x)+k
# Out:
# log(y) == k + 1/2*log(x)

# %%
# Ho ajuntem tot en una sola equació igualada a zero

# %%
sol=(_).lhs()-(_).rhs()

# %%
sol
# Out:
# -k - 1/2*log(x) + log(y)

# %%
# Mirem d'expresar-ho en termes de y com a funció de x

# %%
sol2=solve(sol,y);sol2
# Out:
# [y == e^(k + 1/2*log(x))]

# %%
# Per tal que quedi més simple cal fer algunes suposicions

# %%
assume(x>0);simplify(sol2[0].rhs())
# Out:
# e^(k + 1/2*log(x))

# %%
test=e^k*sqrt(x)

# %%
assume(x>0);simplify(sol2[0].rhs()-test)
# Out:
# -sqrt(x)*e^k + e^(k + 1/2*log(x))

# %%
# El SAGE mo sembla massa bo ni que l'ajudem

# %%
plot((sol2[0].rhs()-test).subs(k=-1),0.00001,5)
# Out:
# Graphics object consisting of 1 graphics primitive
