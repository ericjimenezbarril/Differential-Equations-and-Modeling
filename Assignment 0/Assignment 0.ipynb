# %% [markdown]
# ## CALCULADORA

# %%
5+4/3
# Out:
# 19/3

# %%
(4+5)/3
# Out:
# 3

# %%
cos(0)
# Out:
# 1

# %%
v=[3, 4, -6]

# %%
v[2]
# Out:
# -6

# %%
3^100
# Out:
# 515377520732011331036461129765621272702107522001

# %%
factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
3.0^100
# Out:
# 5.15377520732011e47

# %%
arctan(1)
# Out:
# 1/4*pi

# %%
n(arctan(1)+1)
# Out:
# 1.78539816339745

# %%
N(arctan(1)+1)
# Out:
# 1.78539816339745

# %%
numerical_approx(arctan(1)+1)
# Out:
# 1.78539816339745

# %%
N(arctan(1), digits=50)
# Out:
# 0.78539816339744830961566084581987572104929234984378

# %%
N(arctan(1), 170)
# Out:
# 0.78539816339744830961566084581987572104929234984378

# %%
var("alpha, x, y, z")
# Out:
# (alpha, x, y, z)

# %%
z= sqrt(7*x+y^5-sin(alpha))

# %%
show(z)
# Out:
# sqrt(y^5 + 7*x - sin(alpha))

# %%
jsmath(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-1e9075bc3ca0> in <module>()
# ----> 1 jsmath(z)
#
# NameError: name 'jsmath' is not defined

# %%
latex(z)
# Out:
# \sqrt{y^{5} + 7 \, x - \sin\left(\alpha\right)}

# %%
(3+4*I)^10
# Out:
# 1476984*I - 9653287

# %%
e^(i*pi)
# Out:
# -1

# %%
var('x')
# Out:
# x

# %%
p=(x+1)*(x-1)^2

# %%
q=expand(p)

# %%
q
# Out:
# x^3 - x^2 - x + 1

# %%
factor(q)
# Out:
# (x + 1)*(x - 1)^2

# %%
find_root(q, 0 ,3)
# Out:
# 1.000000000082526

# %%
var("theta")
# Out:
# theta

# %%
find_root(cos(theta)==sin(theta)+1/5, 0, pi/2)
# Out:
# 0.6435011087932845

# %%
time is_prime(2^127 -1)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 11.6 ms
# True

# %%
time factor(2^128 -1)
# Out:
# CPU times: user 0 ns, sys: 47 ms, total: 47 ms
# Wall time: 95.1 ms
# 3 * 5 * 17 * 257 * 641 * 65537 * 274177 * 6700417 * 67280421310721

# %%
reset("a")

# %% [raw]
# theta

# %%
reset()

# %%
theta
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/all_cmdline.py in <module>()
# ----> 1 theta
#
# NameError: name 'theta' is not defined

# %%
f(x)= 1/(1+x^2)

# %%
var("r"); [f(x), f(x+1), f(3), f(r)]
# Out:
# [1/(x^2 + 1), 1/((x + 1)^2 + 1), 1/10, 1/(r^2 + 1)]

# %%
var("x, y")
# Out:
# (x, y)

# %%
diff(f(x))
# Out:
# -2*x/(x^2 + 1)^2

# %%
diff(f(x), x, 4)
# Out:
# 384*x^4/(x^2 + 1)^5 - 288*x^2/(x^2 + 1)^4 + 24/(x^2 + 1)^3

# %%
integrate(f(x), x)
# Out:
# arctan(x)

# %%
var("x")
# Out:
# x

# %%
integral(x*sin(x^2), x)
# Out:
# -1/2*cos(x^2)

# %%
show(integrate(x/(1-x^3), x))
# Out:
# -1/3*sqrt(3)*arctan(1/3*sqrt(3)*(2*x + 1)) + 1/6*log(x^2 + x + 1) - 1/3*log(x - 1)

# %%
limit(sin(x)/x, x=0)
# Out:
# 1

# %%
limit(sin(x)/abs(x), x=0)
# Out:
# und

# %%
limit(sin(x)/abs(x), x=0, dir="minus")
# Out:
# -1

# %%
limit(sin(x)/abs(x), x=0, dir="plus")
# Out:
# 1

# %%
g= piecewise([[(-5,1),(1-x)/2], [(1,8),sqrt(x-1)]])

# %%
plot(g, x, -5, 8)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(cos(x^2), -5, 5, thickness=5, rgbcolor=(0.5,1,0.5), fill = "axis")
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(bessel_J(2, x), 0, 20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()

# %%
var("t")
# Out:
# t

# %%
parametric_plot((cos(t), sin(t)), (t, 0, 2*pi)).show(aspect_ratio=1, frame=true)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var("x, y")
# Out:
# (x, y)

# %%
plot3d(4*x*exp(-x^2-y^2), (x, -2, 2), (y, -2, 2))
# Out:
# Graphics3d Object

# %%
implicit_plot(sin(x*y) + sin(x)*sin(y) == 1, (x,-5,5), (y,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
onda = animate([sin(x+k) for k in srange(0,10,0.5)], xmin=0, xmax=8*pi)
onda.show(delay=30, iterations=1)
# Out:
# Animation with 20 frames

# %%
reset()

# %%
x0  = 0
f   = sin(x) * e^(-x)
p   = plot(f, -1, 5, thickness=2)
dot = point((x0, f(x=x0)), pointsize=80, rgbcolor=(1, 0, 0))

@interact
def _(order=slider([1 .. 12])):
  ft = f.taylor(x, x0, order)
  pt = plot(ft, -1, 5, color='green', thickness=2)
  pretty_print(html(r'$f(x)\;=\;%s$' % latex(f)))
  pretty_print(html(r'$\hat{f}(x;%s)\;=\;%s+\mathcal{O}(x^{%s})$' % (x0, latex(ft), order+1)))
  show(dot + p + pt, ymin=-.5, ymax=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/all_cmdline.py in <module>()
#       4 dot = point((x0, f(x=x0)), pointsize=Integer(80), rgbcolor=(Integer(1), Integer(0), Integer(0)))
#       5
# ----> 6 @interact
#       7 def _(order=slider((ellipsis_range(Integer(1) ,Ellipsis, Integer(12))))):
#       8   ft = f.taylor(x, x0, order)
#
# NameError: name 'interact' is not defined

# %%
@interact 
def myplot(f=x^2):
    show(plot(f, (x, -3, 3)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/all_cmdline.py in <module>()
# ----> 1 @interact
#       2 def myplot(f=x**Integer(2)):
#       3     show(plot(f, (x, -Integer(3), Integer(3))))
#
# NameError: name 'interact' is not defined
