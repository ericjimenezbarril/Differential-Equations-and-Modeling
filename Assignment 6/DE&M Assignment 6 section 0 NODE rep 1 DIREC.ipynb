# %%
# Pràctica 6 secció 0-1

# %%
var("x y");

# %%
eq1=x+y

# %%
eq2=y

# %%
plot=plot_vector_field((eq1,eq2), (x,-2,2), (y,-2,2));plot
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var("t");
x1=function("x1")(t);
y1=function("y1")(t);
eqd1=diff(x1(t),t)==eq1.subs(x=x1(t),y=y1(t));
eqd2=diff(y1(t),t)==eq2.subs(x=x1(t),y=y1(t));
eqd2
# Out:
# diff(y1(t), t) == y1(t)

# %%
sol=desolve_system([eqd1, eqd2],[x1,y1],ics=[0,0.1,0.1]);sol
# Out:
# [x1(t) == 1/10*t*e^t + 1/10*e^t, y1(t) == 1/10*e^t]

# %%
plot1=parametric_plot( (sol[0].rhs(),sol[1].rhs() ),(t,-1,2),color="red")

# %%
plot+plot1
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sol=desolve_system([eqd1, eqd2],[x1,y1],ics=[0,0,1]);sol
# Out:
# [x1(t) == t*e^t, y1(t) == e^t]

# %%
plot2=parametric_plot( (sol[0].rhs(),sol[1].rhs() ),(t,-3,0.8),color="red")

# %%
plot+plot1+plot2
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
sol=desolve_system([eqd1, eqd2],[x1,y1],ics=[0,0,1.5]);sol
# Out:
# [x1(t) == 3/2*t*e^t, y1(t) == 3/2*e^t]

# %%
plot3=parametric_plot( (sol[0].rhs(),sol[1].rhs() ),(t,-10,1/2),color="red")

# %%
sol=desolve_system([eqd1, eqd2],[x1,y1],ics=[0,-1,1]);sol
# Out:
# [x1(t) == t*e^t - e^t, y1(t) == e^t]

# %%
plot4=parametric_plot( (sol[0].rhs(),sol[1].rhs() ),(t,-10,1),color="red")

# %%
plot+plot1+plot2+plot3+plot4
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
A=matrix(CC,[[diff(eq1,x),diff(eq1,y)],[diff(eq2,x),diff(eq2,y)]]);A
# Out:
# [ 1.00000000000000  1.00000000000000]
# [0.000000000000000  1.00000000000000]

# %%
A.eigenvalues()
# Out:
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/repl/ipython_kernel/__main__.py:1: UserWarning: Using generic algorithm for an inexact ring, which will probably give incorrect results due to numerical precision issues.
#   from ipykernel.kernelapp import IPKernelApp
# [1.00000000000000 + 0.316227766016838*I, 1.00000000000000 - 0.316227766016838*I]

# %%
# Dos valors propis reals i positius, iguals, pero en una matriu jacobiana que no diagonalitza. Aquest punt s'anomena un NODE 
# REPULSOR d'UNA SOLA DIRECCIO
