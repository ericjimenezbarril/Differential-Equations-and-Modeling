# %%
# Pràctica 6 secció 3b

# %%
var("x,y,a");a=1/100

# %%
eq1=-a+1.*x^2+2*y^2

# %%
eq2=1.*y+1.*y^2

# %%
# He necesitat possar-li els "1." multiplicant per forçar al SAGE a treballar en mode numèric

# %%
sol=solve([eq1,eq2],x,y);sol
# Out:
# [[x == (-1/10), y == 0], [x == (1/10), y == 0], [x == -1/10*I*sqrt(199), y == -1], [x == 1/10*I*sqrt(199), y == -1]]

# %%
px1=sol[0][0].rhs();px1
# Out:
# -1/10

# %%
py1=sol[0][1].rhs();py1
# Out:
# 0

# %%
px2=sol[1][0].rhs();px2
# Out:
# 1/10

# %%
py2=sol[1][1].rhs();py2
# Out:
# 0

# %%
px3=sol[2][0].rhs();px3
# Out:
# -1/10*I*sqrt(199)

# %%
py3=sol[2][1].rhs();py3
# Out:
# -1

# %%
px4=sol[3][0].rhs();px4
# Out:
# 1/10*I*sqrt(199)

# %%
py4=sol[3][1].rhs();py4
# Out:
# -1

# %%
# Prescindim de les singularitats complexes

# %%
qx=min(px1,px2);qx
# Out:
# -1/10

# %%
qy=min(py1,py2);qy
# Out:
# 0

# %%
plot=plot_vector_field((eq1,eq2), (x,qx-2,qx+2), (y,qy-2,qy+2));plot
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var("t");

# %%
# Estudiem primer que és cada punt singular

# %%
A=matrix([[diff(eq1,x),diff(eq1,y)],[diff(eq2,x),diff(eq2,y)]]).subs(x=px2,y=py2);A
# Out:
# [0.200000000000000                 0]
# [                0                 1]

# %%
A.eigenvalues()
# Out:
# [1/5, 1]

# %%
# Això és un NODE . No cal integrar res per ara.

# %%
# Anem pel darrer punt singular

# %%
A=matrix([[diff(eq1,x),diff(eq1,y)],[diff(eq2,x),diff(eq2,y)]]).subs(x=px1,y=py1);A
# Out:
# [-0.200000000000000                  0]
# [                 0                  1]

# %%
A.eigenvalues()
# Out:
# [-1/5, 1]

# %%
(N(A.eigenvalues()[0]),N(A.eigenvalues()[1]))
# Out:
# (-0.200000000000000, 1.00000000000000)

# %%
# Es una sella

# %%
px=px1;py=py1;h=0.01;step1=0.01;

# %%
vec=A.eigenvectors_right();vec
# Out:
# [(-3602879701896397/18014398509481984, [(1, 0)], 1), (1, [(0, 1)], 1)]

# %%
vec[0][0]
# Out:
# -3602879701896397/18014398509481984

# %%
kt=8;
if(vec[0][0]>0):
    sol=desolve_system_rk4([eq1, eq2],[x,y],ics=[0,px+h*vec[0][1][0][0],py+h*vec[0][1][0][1]],ivar=t,
                       end_points=[qx+kt,qy+kt],step=step1)
elif (vec[0][0]<0):
    sol=desolve_system_rk4([-eq1,-eq2],[x,y],ics=[0,px+h*vec[0][1][0][0],py+h*vec[0][1][0][1]],ivar=t,
                       end_points=[qx+kt,qy+kt],step=step1)

# %%
sol1=[[j,k] for i,j,k in sol]

# %%
if(vec[0][0]<0):
    sep5=list_plot(sol1,color="blue")
elif (vec[0][0]>0):
    sep5=list_plot(sol1,color="red")

# %%
plot+sep5
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
kt=6.1;
if(vec[0][0]>0):
    sol=desolve_system_rk4([eq1, eq2],[x,y],ics=[0,px-h*vec[0][1][0][0],py-h*vec[0][1][0][1]],ivar=t,
                       end_points=[qx+kt,qy+kt],step=step1)
elif (vec[0][0]<0):
    sol=desolve_system_rk4([-eq1,-eq2],[x,y],ics=[0,px-h*vec[0][1][0][0],py-h*vec[0][1][0][1]],ivar=t,
                       end_points=[qx+kt,qy+kt],step=step1)

# %%
sol1=[[j,k] for i,j,k in sol]

# %%
if(vec[0][0]<0):
    sep6=list_plot(sol1,color="blue")
elif (vec[0][0]>0):
    sep6=list_plot(sol1,color="red")

# %%
plot+sep6
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
kt=4.2;
if(vec[1][0]>0):
    sol=desolve_system_rk4([eq1, eq2],[x,y],ics=[0,px+h*vec[1][1][0][0],py+h*vec[1][1][0][1]],ivar=t,
                       end_points=[qx+kt,qy+kt],step=step1)
elif (vec[1][0]<0):
    sol=desolve_system_rk4([-eq1,-eq2],[x,y],ics=[0,px+h*vec[1][1][0][0],py+h*vec[1][1][0][1]],ivar=t,
                       end_points=[qx+kt,qy+kt],step=step1)

# %%
sol1=[[j,k] for i,j,k in sol]

# %%
if(vec[1][0]<0):
    sep7=list_plot(sol1,color="blue")
elif (vec[1][0]>0):
    sep7=list_plot(sol1,color="red")

# %%
plot+sep7
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
kt=4;
if(vec[1][0]>0):
    sol=desolve_system_rk4([eq1, eq2],[x,y],ics=[0,px-h*vec[1][1][0][0],py-h*vec[1][1][0][1]],ivar=t,
                       end_points=[qx+kt,qy+kt],step=step1)
elif (vec[1][0]<0):
    sol=desolve_system_rk4([-eq1,-eq2],[x,y],ics=[0,px-h*vec[1][1][0][0],py-h*vec[1][1][0][1]],ivar=t,
                       end_points=[qx+kt,qy+kt],step=step1)

# %%
sol1=[[j,k] for i,j,k in sol]

# %%
if(vec[1][0]<0):
    sep8=list_plot(sol1,color="blue")
elif (vec[1][0]>0):
    sep8=list_plot(sol1,color="red")

# %%
plot+sep8
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot+sep5+sep6+sep7+sep8
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
# Amb el veiem aquí, i sapiguent que no hi ha més punts singulars, 
# ja podem saber que farà qualsevol altra òrbita que passi per un punt concret.

# %%
px=0;py=0.5;kt=0.7;
sol=desolve_system_rk4([eq1, eq2],[x,y],ics=[0,px,py],ivar=t,
                       end_points=[qx+kt,qy+kt],step=step1)

# %%
sol1=[[j,k] for i,j,k in sol]

# %%
orb1=list_plot(sol1,color="yellow")

# %%
plot+sep5+sep6+sep7+sep8+orb1
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
px=0.;py=0.5;kt=3;sol=desolve_system_rk4([-eq1, -eq2],[x,y],ics=[0,px,py],ivar=t,
                       end_points=[qx+kt,qy+kt],step=step1)

# %%
sol1=[[j,k] for i,j,k in sol]

# %%
orb2=list_plot(sol1,color="yellow")

# %%
plot+sep5+sep6+sep7+sep8+orb1+orb2
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
sol1
# Out:
# [[0.000000000000000, 0.500000000000000],
#  [-0.00482594425703639, 0.4925743186982587],
#  [-0.00950746959874083, 0.485294598221492],
#  [-0.01404993097425766, 0.4781569303097611],
#  [-0.01845844836141232, 0.471157543822848],
#  [-0.02273791894652481, 0.4642927987730576],
#  [-0.02689302857152603, 0.4575591806670443],
#  [-0.0309282624986244, 0.4509532951381521],
#  [-0.03484791553890253, 0.4444718628520122],
#  [-0.03865610158768652, 0.4381117146693081],
#  [-0.04235676260629172, 0.4318697870506862],
#  [-0.04595367708678136, 0.4257431176897893],
#  [-0.04945046803365372, 0.4197288413613082],
#  [-0.05285061049387631, 0.4138241859717999],
#  [-0.05615743866439227, 0.4080264688018146],
#  [-0.05937415260411621, 0.4023330929286042],
#  [-0.06250382457549815, 0.3967415438193698],
#  [-0.06554940503894935, 0.391249386085638],
#  [-0.06851372832178017, 0.3858542603899446],
#  [-0.07139951798178445, 0.3805538804965505],
#  [-0.07420939188420746, 0.3753460304584281],
#  [-0.07694586700954383, 0.3702285619332266],
#  [-0.07961136400842055, 0.3651993916213704],
#  [-0.08220821151871802, 0.3602564988198547],
#  [-0.08473865025906364, 0.3553979230856884],
#  [-0.08720483691188949, 0.3506217620032936],
#  [-0.08960884780837221, 0.3459261690505039],
#  [-0.09195268242676434, 0.3413093515581193],
#  [-0.09423826671487585, 0.3367695687582667],
#  [-0.09646745624676882, 0.3323051299170904],
#  [-0.09864203922308173, 0.3279143925475493],
#  [-0.1007637393238002, 0.3235957606983422],
#  [-0.1028342184217327, 0.3193476833152034],
#  [-0.1048550791644312, 0.3151686526710227],
#  [-0.106827867431815, 0.3110572028614402],
#  [-0.1087540746763047, 0.3070119083627535],
#  [-0.1106351401518586, 0.3030313826491443],
#  [-0.1124724530379081, 0.2991142768663994],
#  [-0.1142673544638325, 0.2952592785594493],
#  [-0.1160211394392675, 0.2914651104511952],
#  [-0.1177350586952298, 0.2877305292702271],
#  [-0.1194103204407428, 0.284054324625166],
#  [-0.1210480920393728, 0.2804353179234789],
#  [-0.122649501609826, 0.2768723613327319],
#  [-0.1242156395545178, 0.2733643367823496],
#  [-0.125747560019796, 0.2699101550040489],
#  [-0.1272462822912931, 0.2665087546092123],
#  [-0.1287127921276811, 0.2631591012015495],
#  [-0.1301480430359177, 0.2598601865234849],
#  [-0.1315529574909011, 0.2566110276347829],
#  [-0.1329284281022849, 0.2534106661220002],
#  [-0.1342753187310532, 0.2502581673374234],
#  [-0.1355944655583123, 0.2471526196662161],
#  [-0.1368866781086212, 0.2440931338205641],
#  [-0.1381527402300556, 0.2410788421596636],
#  [-0.1393934110330818, 0.2381088980344568],
#  [-0.1406094257902058, 0.2351824751560687],
#  [-0.1418014967982561, 0.2322987669869515],
#  [-0.142970314205063, 0.2294569861537901],
#  [-0.1441165468021995, 0.2266563638812653],
#  [-0.1452408427853668, 0.2238961494458158],
#  [-0.1463438304839197, 0.2211756096485796],
#  [-0.1474261190609543, 0.2184940283067332],
#  [-0.1484882991853026, 0.2158507057624835],
#  [-0.1495309436767133, 0.2132449584090018],
#  [-0.1505546081254316, 0.2106761182326218],
#  [-0.1515598314873275, 0.208143532370653],
#  [-0.1525471366556678, 0.205646562684193],
#  [-0.1535170310105695, 0.2031845853453471],
#  [-0.1544700069471207, 0.2007569904382913],
#  [-0.1554065423831075, 0.198363181573641],
#  [-0.1563271012472397, 0.1960025755156085],
#  [-0.1572321339487205, 0.193674601821459],
#  [-0.15812207782897, 0.1913787024927921],
#  [-0.1589973575962682, 0.1891143316382008],
#  [-0.1598583857440488, 0.1868809551468748],
#  [-0.16070556295354, 0.1846780503727372],
#  [-0.1615392784814139, 0.1825051058287204],
#  [-0.1623599105330764, 0.1803616208908015],
#  [-0.1631678266221991, 0.1782471055114368],
#  [-0.1639633839170653, 0.1761610799420492],
#  [-0.1647469295742791, 0.1741030744642344],
#  [-0.165518801060355, 0.1720726291293698],
#  [-0.1662793264616894, 0.1700692935063202],
#  [-0.167028824783385, 0.1680926264369477],
#  [-0.1677676062373819, 0.1661421957991453],
#  [-0.1684959725203287, 0.1642175782771265],
#  [-0.1692142170816035, 0.1623183591387107],
#  [-0.1699226253818819, 0.1604441320193587],
#  [-0.170621475142626, 0.1585944987127196],
#  [-0.1713110365868549, 0.1567690689674617],
#  [-0.1719915726715413, 0.1549674602901674],
#  [-0.1726633393119612, 0.153189297754083],
#  [-0.1733265855983117, 0.1514342138135198],
#  [-0.1739815540048982, 0.1497018481237137],
#  [-0.1746284805921763, 0.1479918473659566],
#  [-0.1752675952019258, 0.146303865077819],
#  [-0.1758991216458186, 0.1446375614882933],
#  [-0.1765232778876319, 0.1429926033576907],
#  [-0.1771402762193506, 0.1413686638221328],
#  [-0.1777503234313859, 0.1397654222424847],
#  [-0.1783536209771351, 0.1381825640575819],
#  [-0.1789503651320923, 0.1366197806416093],
#  [-0.179540747147714, 0.135076769165495],
#  [-0.1801249534002336, 0.1335532324621893],
#  [-0.180703165534613, 0.1320488788956995],
#  [-0.1812755606038074, 0.1305634222337611],
#  [-0.1818423112035183, 0.1290965815240269],
#  [-0.1824035856025965, 0.1276480809736612],
#  [-0.1829595478692545, 0.1262176498322292],
#  [-0.1835103579932394, 0.1248050222777788],
#  [-0.1840561720041116, 0.1234099373060115],
#  [-0.1845971420857689, 0.1220321386224454],
#  [-0.1851334166873509, 0.1206713745374773],
#  [-0.1856651406306504, 0.1193273978642523],
#  [-0.1861924552141577, 0.1179999658192528],
#  [-0.1867154983138551, 0.1166888399255249],
#  [-0.1872344044808761, 0.1153937859184579],
#  [-0.1877493050361386, 0.114114573654041],
#  [-0.1882603281620586, 0.1128509770195193],
#  [-0.1887675989914444, 0.1116027738463777],
#  [-0.1892712396936686, 0.1103697458255813],
#  [-0.1897713695582136, 0.1091516784250036],
#  [-0.1902681050756777, 0.1079483608089779],
#  [-0.1907615600163315, 0.1067595857599079],
#  [-0.1912518455063051, 0.1055851496018754],
#  [-0.1917390701014886, 0.1044248521261864],
#  [-0.1922233398592221, 0.1032784965187991],
#  [-0.1927047584078495, 0.1021458892895763],
#  [-0.1931834270142079, 0.1010268402033112],
#  [-0.1936594446491217, 0.09992116221247264],
#  [-0.1941329080509671, 0.09882867139162109],
#  [-0.1946039117873717, 0.09774918687344702],
#  [-0.1950725483151107, 0.09668253078638409],
#  [-0.1955389080382576, 0.0956285281937525],
#  [-0.1960030793646497, 0.09458700703438878],
#  [-0.1964651487607196, 0.09355779806471937],
#  [-0.1969252008047492, 0.09254073480223722],
#  [-0.1973833182385954, 0.09153565347034193],
#  [-0.1978395820179378, 0.09054239294450465],
#  [-0.1982940713610956, 0.08956079469972107],
#  [-0.1987468637964597, 0.0885907027592162],
#  [-0.1991980352085849, 0.08763196364436635],
#  [-0.1996476598829839, 0.08668442632580452],
#  [-0.2000958105496653, 0.08574794217567662],
#  [-0.200542558425455, 0.08482236492101677],
#  [-0.2009879732551396, 0.08390755059821127],
#  [-0.2014321233514684, 0.08300335750852131],
#  [-0.2018750756340509, 0.082109646174636],
#  [-0.2023168956671831, 0.08122627929822746],
#  [-0.202757647696637, 0.08035312171848134],
#  [-0.2031973946854454, 0.07949004037157639],
#  [-0.2036361983487122, 0.07863690425108771],
#  [-0.2040741191874798, 0.07779358436928918],
#  [-0.2045112165216822, 0.07695995371933113],
#  [-0.2049475485222106, 0.0761358872382702],
#  [-0.2053831722421214, 0.07532126177092877],
#  [-0.2058181436470097, 0.07451595603456254],
#  [-0.2062525176445767, 0.07371985058431475],
#  [-0.206686348113413, 0.0729328277794368],
#  [-0.2071196879310236, 0.07215477175025538],
#  [-0.207552589001116, 0.07138556836586675],
#  [-0.2079851022801752, 0.07062510520253948],
#  [-0.2084172778033451, 0.06987327151280745],
#  [-0.2088491647096392, 0.06912995819523557],
#  [-0.2092808112664993, 0.06839505776484096],
#  [-0.2097122648937218, 0.06766846432415306],
#  [-0.210143572186772, 0.06695007353489646],
#  [-0.210574778939502, 0.06623978259028081],
#  [-0.2110059301662919, 0.06553749018788259],
#  [-0.2114370701236316, 0.06484309650310388],
#  [-0.2118682423311576, 0.06415650316319381],
#  [-0.212299489592163, 0.0634776132218187],
#  [-0.2127308540135959, 0.06280633113416735],
#  [-0.21316237702556, 0.06214256273257823],
#  [-0.2135940994003334, 0.06148621520267587],
#  [-0.2140260612709187, 0.06083719706000382],
#  [-0.2144583021491395, 0.06019541812714224],
#  [-0.2148908609432945, 0.05956078951129824],
#  [-0.2153237759753841, 0.05893322358235758],
#  [-0.2157570849979208, 0.05831263395138654],
#  [-0.2161908252103356, 0.05769893544957325],
#  [-0.2166250332749929, 0.05709204410759779],
#  [-0.2170597453328243, 0.05649187713542094],
#  [-0.217494997018593, 0.05589835290248166],
#  [-0.2179308234757987, 0.0553113909182934],
#  [-0.2183672593712351, 0.05473091181343012],
#  [-0.2188043389092077, 0.05415683732089251],
#  [-0.219242095845424, 0.05358909025784583],
#  [-0.2196805635005636, 0.05302759450772035],
#  [-0.2201197747735389, 0.05247227500266623],
#  [-0.2205597621544547, 0.05192305770635438],
#  [-0.2210005577372755, 0.05137986959711545],
#  [-0.2214421932322084, 0.05084263865140904],
#  [-0.2218846999778111, 0.05031129382761561],
#  [-0.2223281089528318, 0.0497857650501437],
#  [-0.2227724507877885, 0.04926598319384512],
#  [-0.223217755776297, 0.04875188006873137],
#  [-0.2236640538861527, 0.04824338840498414],
#  [-0.2241113747701745, 0.04774044183825352],
#  [-0.2245597477768177, 0.04724297489523725],
#  [-0.2250092019605623, 0.04675092297953472],
#  [-0.2254597660920833, 0.04626422235776975],
#  [-0.2259114686682088, 0.04578281014597588],
#  [-0.2263643379216737, 0.04530662429623854],
#  [-0.2268184018306728, 0.04483560358358826],
#  [-0.227273688128221, 0.04436968759313959],
#  [-0.2277302243113244, 0.04390881670747],
#  [-0.2281880376499705, 0.04345293209423377],
#  [-0.2286471551959398, 0.04300197569400566],
#  [-0.2291076037914462, 0.04255589020834922],
#  [-0.2295694100776106, 0.042114619088105],
#  [-0.2300326005027725, 0.04167810652189389],
#  [-0.2304972013306442, 0.04124629742483083],
#  [-0.2309632386483136, 0.0408191374274445],
#  [-0.2314307383740985, 0.04039657286479846],
#  [-0.2318997262652577, 0.0399785507658095],
#  [-0.2323702279255634, 0.03956501884275897],
#  [-0.2328422688127389, 0.03915592548099298],
#  [-0.2333158742457655, 0.03875121972880748],
#  [-0.2337910694120631, 0.03835085128751436],
#  [-0.2342678793745482, 0.03795477050168462],
#  [-0.2347463290785728, 0.03756292834956505],
#  [-0.235226443358749, 0.03717527643366477],
#  [-0.2357082469456612, 0.03679176697150793],
#  [-0.2361917644724716, 0.03641235278654936],
#  [-0.2366770204814206, 0.03603698729924953],
#  [-0.2371640394302265, 0.03566562451830581],
#  [-0.2376528456983876, 0.03529821903203653],
#  [-0.2381434635933902, 0.03493472599991495],
#  [-0.2386359173568249, 0.03457510114424985],
#  [-0.239130231170415, 0.03421930074200998],
#  [-0.2396264291619601, 0.03386728161678919],
#  [-0.2401245354111974, 0.03351900113090965],
#  [-0.2406245739555835, 0.03317441717766013],
#  [-0.2411265687960003, 0.0328334881736668],
#  [-0.2416305439023868, 0.03249617305139374],
#  [-0.2421365232193008, 0.03216243125177073],
#  [-0.2426445306714113, 0.03183222271694559],
#  [-0.2431545901689262, 0.03150550788315877],
#  [-0.2436667256129564, 0.03118224767373759],
#  [-0.2441809609008196, 0.03086240349220791],
#  [-0.2446973199312856, 0.03054593721552086],
#  [-0.2452158266097666, 0.0302328111873923],
#  [-0.2457365048534534, 0.02992298821175292],
#  [-0.2462593785964009, 0.02961643154630674],
#  [-0.2467844717945651, 0.0293131048961959],
#  [-0.2473118084307927, 0.0290129724077697],
#  [-0.2478414125197679, 0.02871599866245589],
#  [-0.2483733081129151, 0.02842214867073211],
#  [-0.2489075193032632, 0.02813138786619576],
#  [-0.2494440702302712, 0.02784368209973025],
#  [-0.2499829850846177, 0.02755899763376578],
#  [-0.2505242881129572, 0.02727730113663299],
#  [-0.2510680036226436, 0.02699855967700755],
#  [-0.2516141559864248, 0.02672274071844405],
#  [-0.2521627696471082, 0.02644981211399751],
#  [-0.2527138691222011, 0.02617974210093078],
#  [-0.2532674790085263, 0.02591249929550634],
#  [-0.2538236239868153, 0.02564805268786075],
#  [-0.2543823288262813, 0.0253863716369604],
#  [-0.2549436183891734, 0.02512742586563685],
#  [-0.2555075176353135, 0.02487118545570044],
#  [-0.2560740516266188, 0.02461762084313061],
#  [-0.25664324553161, 0.02436670281334159],
#  [-0.2572151246299084, 0.024118402496522],
#  [-0.2577897143167228, 0.02387269136304708],
#  [-0.2583670401073284, 0.02362954121896213],
#  [-0.2589471276415389, 0.02338892420153596],
#  [-0.2595300026881735, 0.02315081277488294],
#  [-0.2601156911495212, 0.02291517972565261],
#  [-0.2607042190658029, 0.02268199815878539],
#  [-0.2612956126196341, 0.02245124149333335],
#  [-0.2618898981404887, 0.02222288345834483],
#  [-0.2624871021091664, 0.02199689808881178],
#  [-0.2630872511622652, 0.02177325972167864],
#  [-0.2636903720966597, 0.02155194299191171],
#  [-0.2642964918739882, 0.02133292282862793],
#  [-0.264905637625149, 0.02111617445128203],
#  [-0.265517836654808, 0.02090167336591095],
#  [-0.2661331164459196, 0.02068939536143459],
#  [-0.2667515046642614, 0.02047931650601188],
#  [-0.267373029162985, 0.02027141314345113],
#  [-0.2679977179871848, 0.02006566188967392],
#  [-0.2686255993784855, 0.01986203962923123],
#  [-0.2692567017796504, 0.01966052351187134],
#  [-0.269891053839212, 0.01946109094915818],
#  [-0.2705286844161268, 0.01926371961113965],
#  [-0.2711696225844548, 0.01906838742306466],
#  [-0.2718138976380668, 0.01887507256214839],
#  [-0.2724615390953802, 0.01868375345438477],
#  [-0.2731125767041242, 0.0184944087714053],
#  [-0.2737670404461382, 0.01830701742738366],
#  [-0.2744249605422024, 0.01812155857598511],
#  [-0.2750863674569045, 0.01793801160735999],
#  [-0.275751291903542, 0.01775635614518059],
#  [-0.2764197648490637, 0.01757657204372073],
#  [-0.2770918175190511, 0.0173986393849771],
#  [-0.2777674814027408, 0.01722253847583197],
#  [-0.278446788258091, 0.01704824984525625],
#  [-0.2791297701168926, 0.01687575424155258]]
