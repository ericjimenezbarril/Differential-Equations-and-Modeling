# %%
# Pràctica 6 secció 0-4

# %%
var("x y");

# %%
eq1=-y

# %%
eq2=x

# %%
plot=plot_vector_field((eq1,eq2), (x,-2,2), (y,-2,2));plot
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var("t");
x1=function("x1")(t);
y1=function("y1")(t);
eqd1=diff(x1(t),t)==eq1.subs(x=x1(t),y=y1(t));
eqd2=diff(y1(t),t)==eq2.subs(x=x1(t),y=y1(t));
eqd2
# Out:
# diff(y1(t), t) == x1(t)

# %%
sol=desolve_system([eqd1, eqd2],[x1,y1],ics=[0,0.5,0.5]);sol
# Out:
# [x1(t) == 1/2*cos(t) - 1/2*sin(t), y1(t) == 1/2*cos(t) + 1/2*sin(t)]

# %%
plot1=parametric_plot( (sol[0].rhs(),sol[1].rhs() ),(t,-5,2.5),color="red")

# %%
plot+plot1
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sol=desolve_system([eqd1, eqd2],[x1,y1],ics=[0,-1,1]);sol
# Out:
# [x1(t) == -cos(t) - sin(t), y1(t) == cos(t) - sin(t)]

# %%
plot2=parametric_plot( (sol[0].rhs(),sol[1].rhs() ),(t,-5,2.5),color="red")

# %%
plot+plot1+plot2
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
A=matrix(CC,[[diff(eq1,x),diff(eq1,y)],[diff(eq2,x),diff(eq2,y)]]);A
# Out:
# [0.000000000000000 -1.00000000000000]
# [ 1.00000000000000 0.000000000000000]

# %%
A.eigenvalues()
# Out:
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/repl/ipython_kernel/__main__.py:1: UserWarning: Using generic algorithm for an inexact ring, which will probably give incorrect results due to numerical precision issues.
#   from ipykernel.kernelapp import IPKernelApp
# [1.00000000000000*I, -1.00000000000000*I]

# %%
# Dos valors propis complexes i amb part real nul·la. 
# Es possible que aquest punt estigui rodejat d'òrbites periòdiques. En aquest cas el punt s'anomena un CENTRE
# Però si no és així semblarà un FOCUS i s'anomena un FOCUS FEBLE (atractor o repulsor).
# El problema de determinar en qualsevol cas si un punt singular amb dos valors propies complexes i de part real nul·la
# és un CENTRE o un FOCUS FEBLE és encara un problema obert. Només està resolt en el cas de sistemes lineals, sistemes
# quadràtics i algunes families concretes de sistemes.
