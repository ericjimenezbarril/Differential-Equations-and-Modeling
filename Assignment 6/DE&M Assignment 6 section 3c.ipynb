# %%
# Pràctica 6 secció 3c

# %%
var("x,y,a");a=-1/10

# %%
eq1=-a+1.*x^2+2*y^2

# %%
eq2=1.*y+1.*y^2

# %%
# He necesitat possar-li els "1." multiplicant per forçar al SAGE a treballar en mode numèric

# %%
sol=solve([eq1,eq2],x,y);sol
# Out:
# [[x == -1/10*I*sqrt(10), y == 0], [x == 1/10*I*sqrt(10), y == 0], [x == -1/10*I*sqrt(21)*sqrt(10), y == -1], [x == 1/10*I*sqrt(21)*sqrt(10), y == -1]]

# %%
px1=sol[0][0].rhs();px1
# Out:
# -1/10*I*sqrt(10)

# %%
py1=sol[0][1].rhs();py1
# Out:
# 0

# %%
px2=sol[1][0].rhs();px2
# Out:
# 1/10*I*sqrt(10)

# %%
py2=sol[1][1].rhs();py2
# Out:
# 0

# %%
px3=sol[2][0].rhs();px3
# Out:
# -1/10*I*sqrt(21)*sqrt(10)

# %%
py3=sol[2][1].rhs();py3
# Out:
# -1

# %%
px4=sol[3][0].rhs();px4
# Out:
# 1/10*I*sqrt(21)*sqrt(10)

# %%
py4=sol[3][1].rhs();py4
# Out:
# -1

# %%
# Totes les singularitats son complexes
# L'únic que pdem fer es tractar de dibuixar algunes órbites

# %%
plot=plot_vector_field((eq1,eq2), (x,-2,+2), (y,-2,+2));plot
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# Veiem que el camp de vectors no es diferencia massa del que teniem per a>0

# %%
var("t");

# %%
px=-2;py=0.5;kt=0.7;step1=0.01
sol=desolve_system_rk4([eq1, eq2],[x,y],ics=[0,px,py],ivar=t,
                       end_points=[kt,kt],step=step1)

# %%
sol1=[[j,k] for i,j,k in sol]

# %%
orb1=list_plot(sol1,color="yellow")

# %%
plot+orb1
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
px=-2;py=-0.5;kt=2;
sol=desolve_system_rk4([eq1, eq2],[x,y],ics=[0,px,py],ivar=t,
                       end_points=[kt,kt],step=step1)

# %%
sol1=[[j,k] for i,j,k in sol]

# %%
orb2=list_plot(sol1,color="yellow")

# %%
plot+orb1+orb2
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
px=-2;py=0.1;kt=2;
sol=desolve_system_rk4([eq1, eq2],[x,y],ics=[0,px,py],ivar=t,
                       end_points=[kt,kt],step=step1)

# %%
sol1=[[j,k] for i,j,k in sol]

# %%
orb3=list_plot(sol1,color="yellow")

# %%
plot+orb1+orb2+orb3
# Out:
# Graphics object consisting of 4 graphics primitives
