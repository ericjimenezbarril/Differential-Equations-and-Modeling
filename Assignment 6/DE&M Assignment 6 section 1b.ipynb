# %%
# Pràctica 6 secció 1b

# %%
var("x y");

# %%
eq1=x+2*y-1

# %%
eq2=x+3*y+2

# %%
sol=solve([eq1,eq2],x,y);sol
# Out:
# [[x == 7, y == -3]]

# %%
px=sol[0][0].rhs();px
# Out:
# 7

# %%
py=sol[0][1].rhs();py
# Out:
# -3

# %%
plot=plot_vector_field((eq1,eq2), (x,px-2,px+2), (y,py-2,py+2));plot
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var("t");
x1=function("x1")(t);
y1=function("y1")(t);
eqd1=diff(x1(t),t)==eq1.subs(x=x1(t),y=y1(t));
eqd2=diff(y1(t),t)==eq2.subs(x=x1(t),y=y1(t));
eqd2
# Out:
# diff(y1(t), t) == x1(t) + 3*y1(t) + 2

# %%
sol=desolve_system([eqd1, eqd2],[x1,y1],ics=[0,px+0.5,py+0.5]);sol
# Out:
# [x1(t) == 1/6*(sqrt(3)*sinh(sqrt(3)*t) + 3*cosh(sqrt(3)*t))*e^(2*t) + 7,
#  y1(t) == 1/6*(2*sqrt(3)*sinh(sqrt(3)*t) + 3*cosh(sqrt(3)*t))*e^(2*t) - 3]

# %%
plot1=parametric_plot( (sol[0].rhs(),sol[1].rhs() ),(t,-1.2,.38),color="yellow")

# %%
plot+plot1
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sol=desolve_system([eqd1, eqd2],[x1,y1],ics=[0,px-0.5,py-0.5]);sol
# Out:
# [x1(t) == -1/6*(sqrt(3)*sinh(sqrt(3)*t) + 3*cosh(sqrt(3)*t))*e^(2*t) + 7,
#  y1(t) == -1/6*(2*sqrt(3)*sinh(sqrt(3)*t) + 3*cosh(sqrt(3)*t))*e^(2*t) - 3]

# %%
plot2=parametric_plot( (sol[0].rhs(),sol[1].rhs() ),(t,-1.1,0.38),color="yellow")

# %%
plot+plot1+plot2
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
sol=desolve_system([eqd1, eqd2],[x1,y1],ics=[0,px+0.5,py-0.5]);sol
# Out:
# [x1(t) == -1/2*(sqrt(3)*sinh(sqrt(3)*t) - cosh(sqrt(3)*t))*e^(2*t) + 7,
#  y1(t) == -1/2*cosh(sqrt(3)*t)*e^(2*t) - 3]

# %%
plot3=parametric_plot( (sol[0].rhs(),sol[1].rhs() ),(t,-0.9,0.6),color="yellow")

# %%
sol=desolve_system([eqd1, eqd2],[x1,y1],ics=[0,px-0.5,py+0.5]);sol
# Out:
# [x1(t) == 1/2*(sqrt(3)*sinh(sqrt(3)*t) - cosh(sqrt(3)*t))*e^(2*t) + 7,
#  y1(t) == 1/2*cosh(sqrt(3)*t)*e^(2*t) - 3]

# %%
plot4=parametric_plot( (sol[0].rhs(),sol[1].rhs() ),(t,-0.9,0.6),color="yellow")

# %%
plot+plot1+plot2+plot3+plot4
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
A=matrix([[diff(eq1,x),diff(eq1,y)],[diff(eq2,x),diff(eq2,y)]]);A
# Out:
# [1 2]
# [1 3]

# %%
A.eigenvalues()
# Out:
# [-sqrt(3) + 2, sqrt(3) + 2]

# %%
(N(A.eigenvalues()[0]),N(A.eigenvalues()[1]))
# Out:
# (0.267949192431123, 3.73205080756888)

# %%
# Dos valors propis reals del mateix signe (positiu): Tenim un NODE REPULSOR, no cal dibuixar separatrius
